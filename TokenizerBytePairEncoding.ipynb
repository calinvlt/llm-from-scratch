# %% [markdown]
# <a href="https://colab.research.google.com/github/calinvlt/llm-from-scratch/blob/main/TokenizerBytePairEncoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tiktoken

# %%
from importlib.metadata import version
import tiktoken
print("tiktoken version:", version("tiktoken"))
# Out:
# tiktoken version: 0.12.0

# %%
tokenizer = tiktoken.get_encoding("gpt2")
text = (
    "Hello, do you like cake? <|endoftext|> In the dark spaces"
    "of annotknownPalace"
)

print(tokenizer.encode(text, allowed_special={"<|endoftext|>"}))
print(tokenizer.decode(ids))
# Out:
# [15496, 11, 466, 345, 588, 12187, 30, 220, 50256, 554, 262, 3223, 9029, 1659, 24708, 4002, 11531, 558]
# Hello, do you like cake? <|endoftext|> In the dark spacesof annotknownPalace

# %%
text = "Akwirw ier"
ids = tokenizer.encode(text)

print(ids)
print([tokenizer.decode([id]) for id in ids])
# Out:
# [33901, 86, 343, 86, 220, 959]
# ['Ak', 'w', 'ir', 'w', ' ', 'ier']
